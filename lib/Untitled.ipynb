# %%
import pandas as pd

# %%
user = pd.read_csv('data/yelp_academic_dataset_business.csv')
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2723: DtypeWarning: Columns (6,7,11,25,26) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
user[30:60]
# Out:
#    attributes_Accepts Credit Cards attributes_Accepts Insurance  \
# 30                            True                          NaN
# 31                            True                          NaN
# 32                             NaN                         True
# 33                            True                          NaN
# 34                            True                          NaN
# 35                            True                          NaN
# 36                             NaN                          NaN
# 37                             NaN                          NaN
# 38                            True                          NaN
# 39                            True                          NaN
# 40                            True                          NaN
# 41                             NaN                          NaN
# 42                            True                          NaN
# 43                            True                          NaN
# ...

# %%
data = pd.read_csv('merge.csv')

# %%
data.head()
# Out:
#    Unnamed: 0             business_id                 user_id  stars  \
# 0           0  RQmLQYF2ZoLRF240VE1Vew  1diI7PX0AxbbtiUB7nPbuQ      5
# 1           1  RQmLQYF2ZoLRF240VE1Vew  2_HfgANoSydelB2FSExqWw      3
# 2           2  RQmLQYF2ZoLRF240VE1Vew  3gIfcQq5KxAegwCPXc83cQ      2
# 3           3  RQmLQYF2ZoLRF240VE1Vew  51TIJ6jlsVGWhEvu02433g      5
# 4           4  RQmLQYF2ZoLRF240VE1Vew  66oDhsKSB_eSrhCKiERDow      4
#
#                       types
# 0  Food,Donuts,Coffee & Tea
# 1  Food,Donuts,Coffee & Tea
# 2  Food,Donuts,Coffee & Tea
# 3  Food,Donuts,Coffee & Tea
# 4  Food,Donuts,Coffee & Tea

# %%
df = data.ix[:, 1:4]

# %%
df
# Out:
#                    business_id                 user_id  stars
# 0       RQmLQYF2ZoLRF240VE1Vew  1diI7PX0AxbbtiUB7nPbuQ      5
# 1       RQmLQYF2ZoLRF240VE1Vew  2_HfgANoSydelB2FSExqWw      3
# 2       RQmLQYF2ZoLRF240VE1Vew  3gIfcQq5KxAegwCPXc83cQ      2
# 3       RQmLQYF2ZoLRF240VE1Vew  51TIJ6jlsVGWhEvu02433g      5
# 4       RQmLQYF2ZoLRF240VE1Vew  66oDhsKSB_eSrhCKiERDow      4
# 5       RQmLQYF2ZoLRF240VE1Vew  6teUzcdOBAydncEmvW02zQ      5
# 6       RQmLQYF2ZoLRF240VE1Vew  6ts41fCsDKHbFZaKOMNmVQ      5
# 7       RQmLQYF2ZoLRF240VE1Vew  7GAjxEA-OscXgPt7YFgkBw      5
# 8       RQmLQYF2ZoLRF240VE1Vew  8p4at4zdzCpueAmSBaorZA      5
# 9       RQmLQYF2ZoLRF240VE1Vew  E_nfCKOFFgvbfY0yGg-Oew      5
# 10      RQmLQYF2ZoLRF240VE1Vew  GPI930zIvXhi5I0gvkAa7Q      3
# 11      RQmLQYF2ZoLRF240VE1Vew  GPI930zIvXhi5I0gvkAa7Q      5
# 12      RQmLQYF2ZoLRF240VE1Vew  K2Bc66aRnvqIHvzykWDxjg      4
# 13      RQmLQYF2ZoLRF240VE1Vew  YcbKJqlmfvU1jkYN2pfotw      3
# ...
